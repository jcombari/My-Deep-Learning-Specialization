# %%
import numpy as np

a= np.array([1,2,3,4])
a
# Out:
# array([1, 2, 3, 4])

# %%
import time

a = np.random.rand(1000000)
b = np.random.rand(1000000)

tic =  time.time()
c= np.dot(a,b)
toc =  time.time()

print(a.shape)
print(b.shape)

print("Vertorices version:" + str(1000*(toc-tic)))

c=0
tic =time.time()
for i in range(1000000):
    c+=a[i]*b[i]

toc =  time.time()

print("For loop: " +str(1000*(toc-tic)) + "ms")
# Out:
# (1000000,)
# (1000000,)
# Vertorices version:8.79049301147461
# For loop: 1341.7065143585205ms

# %% [markdown]
# ![image.png](attachment:image.png)
